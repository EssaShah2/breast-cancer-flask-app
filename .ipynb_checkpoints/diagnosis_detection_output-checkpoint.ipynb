# %%
import pickle
import numpy as np
import pandas as pd

# %%
with open('diagonsis_detection.pkl', 'rb') as f:
    pipeline = pickle.load(f)

# %%
features = pipeline.named_steps['columntransformer-1'].feature_names_in_
feature_list = list(features)

# %%
sample_df = pd.DataFrame(
    np.random.rand(1,len(features)), 
    columns = features
)

# %%
sample_df
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.910114      0.691698         0.00214   0.700256         0.568578
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.082722        0.231604             0.481283       0.366877
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                0.400932  ...      0.019113       0.845622         0.752782
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    0.256814          0.440234           0.840113         0.710386
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              0.028132        0.512352                 0.693795
#
# [1 rows x 30 columns]

# %%
prediction = pipeline.predict(sample_df)

# %%
prediction
# Out:
# array([0])
