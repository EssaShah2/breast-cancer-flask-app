# %%
import pickle
import numpy as np
import pandas as pd

# %%
with open('diagonsis_detection.pkl', 'rb') as f:
    pipeline = pickle.load(f)
# Out:
# c:\Users\essas\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator PCA from version 1.7.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\essas\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator ColumnTransformer from version 1.7.2 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
features = pipeline.named_steps['columntransformer-1'].feature_names_in_
feature_list = list(features)

# %%
sample_df = pd.DataFrame(
    np.random.rand(1,len(features)), 
    columns = features
)

# %%
sample_df
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.168786      0.308141        0.560312    0.30323         0.174723
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.453481        0.566281             0.729028         0.3429
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                0.724033  ...      0.672654       0.414702         0.978509
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    0.585049          0.858509           0.499457         0.075613
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              0.313795        0.237861                 0.453707
#
# [1 rows x 30 columns]

# %%
prediction = pipeline.predict(sample_df)

# %%
prediction
# Out:
# array([0])
